# %% [markdown]
# # Building AI-Powered Flood Intelligence System with h2oGPTe and NVIDIA NIM
#
# [![Deploy on NVIDIA](https://img.shields.io/badge/Deploy%20on-NVIDIA%20AI%20Blueprints-76B900?logo=nvidia&logoColor=white)](https://build.nvidia.com)
# [![H2O.ai](https://img.shields.io/badge/Powered%20by-H2O.ai-FFD500)](https://h2o.ai)
#
# ---

# %% [markdown]
# # 🌊 Overview
#
# This blueprint demonstrates an **AI-powered flood intelligence and disaster response system** that combines:
#
# - **h2oGPTe Agent-to-Agent (A2A)**: Advanced AutoML capabilities with Driverless AI for model training and feature engineering
# - **NVIDIA NIM**: State-of-the-art inference with `nvidia/llama-3.3-nemotron-super-49b-v1.5` and other NVIDIA models
# - **NVIDIA NAT Pipeline**: React Agent workflows for multi-agent orchestration
# - **FastMCP Server**: 20+ specialized tools across 5 intelligent agents
# - **Real-time Data Integration**: USGS Water Services, NOAA Forecasts, and Weather APIs
#
# ### 🎯 Use Case: AI for Good - Disaster Response
#
# This system provides:
# - **Real-time flood monitoring** with live data from watersheds and monitoring stations
# - **AI-powered risk assessment** using advanced machine learning models
# - **Emergency response coordination** with automated alerts and evacuation planning
# - **Predictive analytics** for flood forecasting 24-72 hours ahead
# - **AutoML model training** for continuous improvement of prediction accuracy
#
# ### 🏗️ Architecture
#
# ```
# ┌─────────────────────────────────────────────────────────────────┐
# │                      Flood Intelligence System                     │
# ├─────────────────────────────────────────────────────────────────┤
# │                                                                  │
# │  ┌──────────────┐  ┌──────────────┐  ┌──────────────┐         │
# │  │   h2oGPTe    │  │  NVIDIA NIM  │  │  FastMCP     │         │
# │  │  (A2A Mode)  │  │  (Nemotron)  │  │   Server     │         │
# │  └──────┬───────┘  └──────┬───────┘  └──────┬───────┘         │
# │         │                 │                 │                   │
# │         └────────┬────────┴────────┬────────┘                   │
# │                  │                 │                            │
# │         ┌────────▼─────────────────▼────────┐                  │
# │         │    NVIDIA NAT Agent Pipeline      │                  │
# │         │      (React Agent Workflow)       │                  │
# │         └────────┬──────────────────────────┘                  │
# │                  │                                              │
# │    ┌─────────────┴─────────────┐                               │
# │    │    5 Specialized Agents   │                               │
# │    ├───────────────────────────┤                               │
# │    │  1. Data Collector        │ ◄── USGS Water Data           │
# │    │  2. Risk Analyzer         │ ◄── NOAA Flood Alerts         │
# │    │  3. Emergency Responder   │ ◄── Weather APIs              │
# │    │  4. AI Predictor          │                               │
# │    │  5. H2OGPTE ML Agent      │                               │
# │    └───────────────────────────┘                               │
# │                                                                  │
# │  Output: Real-time Monitoring, Alerts, Predictions, ML Models  │
# └─────────────────────────────────────────────────────────────────┘
# ```
#
# ### 🔑 Key Technologies
#
# 1. **h2oGPTe**: Enterprise AI platform with agent mode for AutoML and advanced analytics
# 2. **NVIDIA NIM**: Optimized inference microservices for AI models
# 3. **NVIDIA NAT**: Agent orchestration framework with React-based workflows
# 4. **FastMCP**: Model Context Protocol server for tool integration
# 5. **FastAPI**: High-performance API server for real-time operations
#
# ---
#
# ## 📋 What You'll Learn
#
# - Setting up multi-agent AI systems for disaster response
# - Integrating h2oGPTe for AutoML and model training
# - Using NVIDIA NIM for high-performance inference
# - Building NAT agent workflows with React patterns
# - Implementing FastMCP servers with custom tools
# - Real-time data integration from government APIs
# - Coordinating multiple AI agents for complex tasks
#
# Let's get started! 🚀

# %% [markdown]
# # Section 1: Setup

# %% [markdown]
# ## 📋 Prerequisites
#
# Before running this setup, make sure you have:
#
# ### Required:
# - ✅ **NVIDIA API Key** - Get it from [build.nvidia.com](https://build.nvidia.com)
#   - This key is used for NVIDIA NIM models and services
#
# ### Required:
# - 🔹 **H2OGPTE API Key** - For AutoML and advanced AI features
#   - Please visit [h2ogpte.genai.h2o.ai](https://h2ogpte.genai.h2o.ai/) and login
#   - After logging in navigate to https://h2ogpte.genai.h2o.ai/api to create an API KEY
#
# ---
#
# Ready? Let's collect your API keys! 🔐

# %% [markdown]
# ### Install Python Dependencies
#
# *Please **restart** the kernel after this step. Do not repeat this step after restarting the kernel.*

# %%
import sys

python = sys.executable

# !{python} -m ensurepip --upgrade
# !{python} -m pip install --upgrade pip setuptools wheel
# !{python} -m pip install --upgrade --force-reinstall pandas openai requests python-dotenv

# %% [markdown]
# ---
#
# ## 🔐 Step 1: Collect API Keys
#
# Run the cells below to securely enter your API keys. Your inputs will be hidden for security.
#
# ### What you'll provide:
# 1. **NVIDIA API Key** (required)
# 2. **H2OGPTE API Key** (required)
# 3. **H2OGPTE URL** (required, default provided)
#
# **Note**: Ports are pre-configured in this Launchable (8090 for Web UI)

# %%
# Import required libraries
import getpass
import os
import sys

from dotenv import load_dotenv

print("✅ Libraries imported successfully!")
# Out:
# ✅ Libraries imported successfully!

# %%
# Initialize API keys and URLs
nvidia_api_key = ""
ngc_api_key = ""
h2ogpte_url = "https://h2ogpte.genai.h2o.ai/"
h2ogpte_api_key = ""

# %%
# Collect NVIDIA API Key
print("🔑 Enter your NVIDIA API Key")
print("   Get it from: https://build.nvidia.com")
print()

nvidia_api_key = getpass.getpass("NVIDIA API Key: ")

if not nvidia_api_key or nvidia_api_key.strip() == "":
    raise ValueError(
        "❌ NVIDIA API Key is required! Please run this cell again and provide the key."
    )

print("✅ NVIDIA API Key collected successfully!")
print(f"   Preview: {nvidia_api_key[:10]}...{nvidia_api_key[-4:]}")
# Out:
# 🔑 Enter your NVIDIA API Key
#    Get it from: https://build.nvidia.com
# NVIDIA API Key:  ········
# ✅ NVIDIA API Key collected successfully!
#    Preview: nvapi-Ztxr...DVnK

# %%
# Collect NGC API Key (optional)
print("🔑 Enter your NGC API Key")
print("   Get it from: https://catalog.ngc.nvidia.com/")
print()

ngc_api_key = getpass.getpass("NGC API Key: ")

if not ngc_api_key or ngc_api_key.strip() == "":
    ngc_api_key = ""
    print("⚠️  No API key provided, skipping Local NIM LLM setup")
else:
    print("✅ NGC API Key collected successfully!")
    print(f"   Preview: {ngc_api_key[:10]}...{ngc_api_key[-4:]}")
# Out:
# 🔑 Enter your NGC API Key
#    Get it from: https://catalog.ngc.nvidia.com/
# NGC API Key:  ········
# ⚠️  No API key provided, skipping Local NIM LLM setup

# %%
# Collect H2OGPTE Credentials
print("🤖 H2OGPTE Configuration")
print("   H2OGPTE provides advanced AutoML and AI agent capabilities")
print()

h2ogpte_url_new = input(f"H2OGPTE URL [{h2ogpte_url}]: ").strip()
h2ogpte_api_key = getpass.getpass("H2OGPTE API Key: ")

if h2ogpte_url_new and h2ogpte_url_new.startswith("https://h2ogpte."):
    h2ogpte_url = h2ogpte_url_new

if not h2ogpte_api_key or h2ogpte_api_key.strip() == "":
    print("⚠️  No API key provided, Please provide H2OGPTE API KEY to proceed!")
    h2ogpte_api_key = ""
else:
    print("✅ H2OGPTE configured successfully!")
    print(f"   URL: {h2ogpte_url}")
    print(f"   API Key Preview: {h2ogpte_api_key[:10]}...{h2ogpte_api_key[-4:]}")
# Out:
# 🤖 H2OGPTE Configuration (Optional)
#    H2OGPTE provides advanced AutoML and AI agent capabilities
#    If you don't have access, just press Enter to skip
# Do you have H2OGPTE access? (yes/no) [no]:  yes
# H2OGPTE URL [https://h2ogpte.cloud-dev.h2o.dev]:  https://h2ogpte.genai.h2o.ai/
# H2OGPTE API Key:  ········
# ✅ H2OGPTE configured successfully!
#    URL: https://h2ogpte.genai.h2o.ai/
#    API Key Preview: sk-Tnro3Qk...Bf9s

# %% [markdown]
# ---
#
# ## 📝 Step 2: Generate Configuration File
#
# Now we'll create the environment configuration file with all the settings.

# %%
def create_env_file(
    nvidia_api_key,
    ngc_api_key,
    h2ogpte_api_key,
    h2ogpte_url,
    output_path="./flood_intelligence.env",
):
    """
    Create the environment configuration file for the Flood Intelligence application.

    Parameters:
    - nvidia_api_key: NVIDIA API key (used for both NVIDIA_API_KEY)
    - ngc_api_key: NGC API key (used for NGC_API_KEY)
    - h2ogpte_api_key: H2OGPTE API key (can be empty string if not used)
    - h2ogpte_url: H2OGPTE service URL
    - output_path: Where to save the env file

    Note: Ports are pre-configured in the Launchable:
    - WEB_PORT: 8090 (fixed)
    """

    env_content = f"""# ==============================================================================
# API KEYS
# ==============================================================================

NVIDIA_API_KEY={nvidia_api_key}
NGC_API_KEY={ngc_api_key}
H2OGPTE_API_KEY={h2ogpte_api_key}

# ==============================================================================
# H2OGPTE CONFIGURATION
# ==============================================================================

# H2OGPTE service URL
H2OGPTE_URL={h2ogpte_url}

# H2OGPTE model to use
H2OGPTE_MODEL=claude-3-7-sonnet-20250219

# ==============================================================================
# WEB APPLICATION IMAGE CONFIGURATION
# ==============================================================================

WEB_IMAGE_REGISTRY=h2oairelease
WEB_IMAGE_REPOSITORY=h2oai-floodintelligence-app
WEB_IMAGE_TAG=v1.2.0

WEB_PORT=8090

# ==============================================================================
# REDIS CONFIGURATION
# ==============================================================================

REDIS_IMAGE_REGISTRY=docker.io
REDIS_IMAGE_REPOSITORY=redis
REDIS_IMAGE_TAG=8.2.1

REDIS_ENABLED=true

# ==============================================================================
# NVIDIA NIM LLM CONFIGURATION (Optional)
# ==============================================================================

NIMLLM_IMAGE=nvcr.io/nim/nvidia/llama-3_3-nemotron-super-49b-v1_5:1.12.0

NIMLLM_PORT=8989

"""

    # Write to file
    with open(output_path, "w") as f:
        f.write(env_content)

    return output_path


print("✅ Helper function created successfully!")
# Out:
# ✅ Helper function created successfully!

# %%
# Generate the environment file
print("🔨 Generating environment configuration file...")
print()

env_file_path = create_env_file(
    nvidia_api_key=nvidia_api_key,
    ngc_api_key=ngc_api_key,
    h2ogpte_api_key=h2ogpte_api_key,
    h2ogpte_url=h2ogpte_url,
)

print("✅ Configuration file created successfully!")
print(f"   Location: {os.path.abspath(env_file_path)}")
print()
print("📋 Configuration Summary:")
print(f"   NVIDIA API Key: {nvidia_api_key[:10]}...{nvidia_api_key[-4:]}")
if h2ogpte_api_key:
    print(f"   H2OGPTE API Key: {h2ogpte_api_key[:10]}...{h2ogpte_api_key[-4:]}")
    print(f"   H2OGPTE URL: {h2ogpte_url}")
else:
    print("   H2OGPTE: Not configured (optional)")
print()
print("🔌 Pre-configured Ports:")
print("   Web UI Port: 8090 (fixed)")
# Out:
# 🔨 Generating environment configuration file...
#
# ✅ Configuration file created successfully!
#    Location: /home/ubuntu/h2oai-flood-intelligence-agent/flood_intelligence.env
#
# 📋 Configuration Summary:
#    NVIDIA API Key: nvapi-Ztxr...DVnK
#    H2OGPTE API Key: sk-Tnro3Qk...Bf9s
#    H2OGPTE URL: https://h2ogpte.genai.h2o.ai/
#
# 🔌 Pre-configured Ports:
#    Web UI Port: 8090 (fixed)

# %%
# Load the environment variables from the created file

load_dotenv("./flood_intelligence.env")
# Out:
# True

# %% [markdown]
# ---
#
# ## 🐳 Step 3: Pull Docker Images
#
# Now we'll authenticate with Docker registries and pull the required images.
#
# This may take 5-10 minutes depending on your connection speed.

# %% [markdown]
# ### Pull Web application image

# %%
# !docker pull h2oairelease/h2oai-floodintelligence-app:v1.2.0
# Out:
# v1.2.0: Pulling from h2oairelease/h2oai-floodintelligence-app
#
# aca0a130: Pulling fs layer
# 3bd72563: Pulling fs layer
# e18d7fdb: Pulling fs layer
# 50a50582: Pulling fs layer
# 8589da02: Pulling fs layer
# 35904449: Pulling fs layer
# f2b7539a: Pulling fs layer
# 874c26a4: Pulling fs layer
# b4c76d98: Pulling fs layer
# bba333a8: Pulling fs layer
# 9d591b56: Pulling fs layer
# 86a5e1b0: Pulling fs layer
# 87aa19e9: Pulling fs layer
# 759b7597: Pulling fs layer
# Digest: sha256:c0649b5f068a73838137e281db77cf9694b8168b7cf234069ca2441dba8a9c24
# Status: Downloaded newer image for h2oairelease/h2oai-floodintelligence-app:v1.2.0
# docker.io/h2oairelease/h2oai-floodintelligence-app:v1.2.0

# %%
# !docker image ls
# Out:
#                                                             i Info →   U  In Use
# IMAGE                           ID             DISK USAGE   CONTENT SIZE   EXTRA
# h2oairelease/h2oai-floodinte…   c0649b5f068a       2.67GB          588MB

# %% [markdown]
# ### OPTIONAL - Locally deployed NIM Microservices.
#
#
#
# <p style="background-color: #bdf55d;">
# By default, this notebook will use hosted endpoints for the NVIDIA LLMs. If Nvidia H200 GPU or equivalent is available, you may host a local NIM LLM.
# Otherwise, skip the next few cells
# </p>

# %% [markdown]
# #### Check if Nvidia Drivers are installed and GPU is present

# %%
# Skip if not using locally hosted NIM Microservices.
# !nvidia-smi -L

# %% [markdown]
# #### Authenticate Docker with NGC

# %%
# Skip if not using locally hosted NIM Microservices.
# !echo "${NGC_API_KEY}" | docker login nvcr.io -u '$oauthtoken' --password-stdin

# %% [markdown]
# #### Pull Nvidia NIM LLM Image

# %%
# Skip if not using locally hosted NIM Microservices.

# The image is defined in the env file as NIMLLM_IMAGE
nim_llm_image = os.getenv(
    "NIMLLM_IMAGE", "nvcr.io/nim/nvidia/llama-3_3-nemotron-super-49b-v1_5:1.12.0"
)
nim_llm_image

# %%
# Skip if not using locally hosted NIM Microservices.

# pull image
# !docker pull "${NIMLLM_IMAGE}"

# %%
# Skip if not using locally hosted NIM Microservices.

# check available images
# !docker image ls

# %% [markdown]
# ### Deploy the application using Docker Compose
#
# Run only one of the `docker compose` commands below:

# %% [markdown]
# #### Deploy with a local NVIDIA NIM LLM - **Only if NVIDIA GPU is available and NIM LLM Image was successfully pulled**

# %%
# Skip if not using locally hosted NIM Microservices.

# !docker compose -f ./deployment/nvidia-launchable/docker-compose.yml -f ./deployment/nvidia-launchable/docker-compose.nimllm.yml --env-file ./flood_intelligence.env up -d

# %% [markdown]
# #### If not using local NVIDIA NIM LLM

# %%
# !docker compose -f ./deployment/nvidia-launchable/docker-compose.yml --env-file ./flood_intelligence.env up -d
# Out:
# [+] Running 0/1
#  ⠙ redis Pulling                                                           0.1s
# [+] Running 0/1
#  ⠹ redis Pulling                                                           0.2s
# [+] Running 0/1
#  ⠸ redis Pulling                                                           0.3s
# [+] Running 0/1
#  ⠼ redis Pulling                                                           0.4s
# [+] Running 0/1
#  ⠴ redis Pulling                                                           0.5s
# [+] Running 0/1
#  ⠦ redis Pulling                                                           0.6s
# [+] Running 0/1
#  ⠧ redis Pulling                                                           0.7s
# [+] Running 0/1
#  ⠇ redis Pulling                                                           0.8s
# [+] Running 0/1
#  ⠏ redis Pulling                                                           0.9s
# [+] Running 0/1
#  ⠋ redis Pulling                                                           1.0s
# [+] Running 0/1
#  ⠙ redis Pulling                                                           1.1s
# [+] Running 0/1
#  ⠹ redis Pulling                                                           1.2s
# [+] Running 0/1
#  ⠸ redis Pulling                                                           1.3s
# [+] Running 0/1
#  ⠼ redis Pulling                                                           1.4s
# [+] Running 0/1
#  ⠴ redis Pulling                                                           1.5s
# [+] Running 0/1
#  ⠦ redis Pulling                                                           1.6s
# [+] Running 0/1
#  ⠧ redis Pulling                                                           1.7s
# [+] Running 0/1
#  ⠇ redis Pulling                                                           1.8s
# [+] Running 0/1
#  ⠏ redis Pulling                                                           1.9s
# [+] Running 0/1
#  ⠋ redis Pulling                                                           2.0s
# [+] Running 0/1
#  ⠙ redis Pulling                                                           2.1s
# [+] Running 0/1
#  ⠹ redis Pulling                                                           2.2s
# [+] Running 0/1
#  ⠸ redis Pulling                                                           2.4s
# [+] Running 0/1
#  ⠼ redis Pulling                                                           2.5s
# [+] Running 0/1
#  ⠴ redis Pulling                                                           2.6s
# [+] Running 0/1
#  ⠦ redis Pulling                                                           2.7s
# [+] Running 0/8
#  ⠧ redis [⠀⠀⠀⠀⠀⠀⠀] Pulling                                                 2.8s
#    ⠋ 54e1e08620c3 Pulling fs layer                                         0.0s
#    ⠋ 5c32499ab806 Pulling fs layer                                         0.0s
#    ⠋ ebb6b8512082 Pulling fs layer                                         0.0s
#    ⠋ 7555a6149d73 Pulling fs layer                                         0.0s
#    ⠋ faa43fe37ea4 Pulling fs layer                                         0.0s
#    ⠋ fa3ef5872501 Pulling fs layer                                         0.0s
#    ⠋ 4f4fb700ef54 Pulling fs layer                                         0.0s
# [+] Running 0/8
#  ⠇ redis [⠀⠀⠀⠀⠀⠀⠀] Pulling                                                 2.9s
#    ⠙ 54e1e08620c3 Pulling fs layer                                         0.1s
#    ⠙ 5c32499ab806 Pulling fs layer                                         0.1s
#    ⠙ ebb6b8512082 Pulling fs layer                                         0.1s
#    ⠙ 7555a6149d73 Pulling fs layer                                         0.1s
#    ⠙ faa43fe37ea4 Pulling fs layer                                         0.1s
#    ⠙ fa3ef5872501 Pulling fs layer                                         0.1s
#    ⠙ 4f4fb700ef54 Pulling fs layer                                         0.1s
# [+] Running 0/8
#  ⠏ redis [⠀⠀⠀⠀⠀⠀⠀] Pulling                                                 3.0s
#    ⠹ 54e1e08620c3 Pulling fs layer                                         0.2s
#    ⠹ 5c32499ab806 Pulling fs layer                                         0.2s
#    ⠹ ebb6b8512082 Pulling fs layer                                         0.2s
#    ⠹ 7555a6149d73 Pulling fs layer                                         0.2s
#    ⠹ faa43fe37ea4 Pulling fs layer                                         0.2s
#    ⠹ fa3ef5872501 Pulling fs layer                                         0.2s
#    ⠹ 4f4fb700ef54 Pulling fs layer                                         0.2s
# [+] Running 0/8
#  ⠋ redis [⠀⠀⠀⠀⠀⠀⠀] Pulling                                                 3.1s
#    ⠸ 54e1e08620c3 Pulling fs layer                                         0.3s
#    ⠸ 5c32499ab806 Pulling fs layer                                         0.3s
#    ⠸ ebb6b8512082 Pulling fs layer                                         0.3s
#    ⠸ 7555a6149d73 Pulling fs layer                                         0.3s
#    ⠸ faa43fe37ea4 Pulling fs layer                                         0.3s
#    ⠸ fa3ef5872501 Pulling fs layer                                         0.3s
#    ⠸ 4f4fb700ef54 Pulling fs layer                                         0.3s
# [+] Running 1/8
#  ⠙ redis [⠀⠀⠀⠀⠀⠀⣿] Pulling                                                 3.2s
#    ⠼ 54e1e08620c3 Pulling fs layer                                         0.4s
#    ⠼ 5c32499ab806 Pulling fs layer                                         0.4s
#    ⠼ ebb6b8512082 Pulling fs layer                                         0.4s
#    ⠼ 7555a6149d73 Pulling fs layer                                         0.4s
#    ⠼ faa43fe37ea4 Pulling fs layer                                         0.4s
#    ⠼ fa3ef5872501 Pulling fs layer                                         0.4s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 1/8
#  ⠹ redis [⠀⠀⠀⠀⠀⠀⣿] Pulling                                                 3.3s
#    ⠴ 54e1e08620c3 Pulling fs layer                                         0.5s
#    ⠴ 5c32499ab806 Pulling fs layer                                         0.5s
#    ⠴ ebb6b8512082 Pulling fs layer                                         0.5s
#    ⠴ 7555a6149d73 Pulling fs layer                                         0.5s
#    ⠴ faa43fe37ea4 Pulling fs layer                                         0.5s
#    ⠴ fa3ef5872501 Pulling fs layer                                         0.5s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 1/8
#  ⠸ redis [⠀⠀⠀⠀⠀⠀⣿] Pulling                                                 3.4s
#    ⠦ 54e1e08620c3 Pulling fs layer                                         0.6s
#    ⠦ 5c32499ab806 Pulling fs layer                                         0.6s
#    ⠦ ebb6b8512082 Pulling fs layer                                         0.6s
#    ⠦ 7555a6149d73 Pulling fs layer                                         0.6s
#    ⠦ faa43fe37ea4 Pulling fs layer                                         0.6s
#    ⠦ fa3ef5872501 Pulling fs layer                                         0.6s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 1/8
#  ⠼ redis [⠀⠀⠀⠀⠀⠀⣿] Pulling                                                 3.5s
#    ⠧ 54e1e08620c3 Pulling fs layer                                         0.7s
#    ⠧ 5c32499ab806 Pulling fs layer                                         0.7s
#    ⠧ ebb6b8512082 Pulling fs layer                                         0.7s
#    ⠧ 7555a6149d73 Pulling fs layer                                         0.7s
#    ⠧ faa43fe37ea4 Pulling fs layer                                         0.7s
#    ⠧ fa3ef5872501 Pulling fs layer                                         0.7s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 1/8
#  ⠴ redis [⠀⣀⠀⠀⠀⠀⣿] Pulling                                                 3.6s
#    ⠇ 54e1e08620c3 Pulling fs layer                                         0.8s
#    ⠇ 5c32499ab806 Downloading      10.49MB/28.2...                         0.8s
#    ⠇ ebb6b8512082 Pulling fs layer                                         0.8s
#    ⠇ 7555a6149d73 Pulling fs layer                                         0.8s
#    ⠇ faa43fe37ea4 Pulling fs layer                                         0.8s
#    ⠇ fa3ef5872501 Pulling fs layer                                         0.8s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 1/8
#  ⠦ redis [⠀⣶⠀⠀⠀⠀⣿] Pulling                                                 3.7s
#    ⠏ 54e1e08620c3 Pulling fs layer                                         0.9s
#    ⠏ 5c32499ab806 Downloading      22.02MB/28.2...                         0.9s
#    ⠏ ebb6b8512082 Pulling fs layer                                         0.9s
#    ⠏ 7555a6149d73 Pulling fs layer                                         0.9s
#    ⠏ faa43fe37ea4 Pulling fs layer                                         0.9s
#    ⠏ fa3ef5872501 Pulling fs layer                                         0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 4/8
#  ⠧ redis [⠀⣷⣿⣿⠀⣿⣿] Pulling                                                 3.8s
#    ⠋ 54e1e08620c3 Pulling fs layer                                         1.0s
#    ⠋ 5c32499ab806 Downloading      26.21MB/28.2...                         1.0s
#    ✔ ebb6b8512082 Download complete                                        0.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ⠋ faa43fe37ea4 Pulling fs layer                                         1.0s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 5/8
#  ⠇ redis [⣿⣿⣿⣿⠀⣿⣿] Pulling                                                 3.9s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ⠙ 5c32499ab806 Downloading      28.23MB/28.2...                         1.1s
#    ✔ ebb6b8512082 Download complete                                        0.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ⠙ faa43fe37ea4 Pulling fs layer                                         1.1s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 5/8
#  ⠏ redis [⣿⣿⣿⣿⠀⣿⣿] Pulling                                                 4.0s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ⠹ 5c32499ab806 Downloading      28.23MB/28.2...                         1.2s
#    ✔ ebb6b8512082 Download complete                                        0.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ⠹ faa43fe37ea4 Pulling fs layer                                         1.2s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 5/8
#  ⠋ redis [⣿⣿⣿⣿⡀⣿⣿] 31.37MB / 52.42MB Pulling                               4.1s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ⠸ 5c32499ab806 Extracting      1 s                                      1.3s
#    ✔ ebb6b8512082 Download complete                                        0.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ⠸ faa43fe37ea4 Downloading      3.146MB/24.1...                         1.3s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 5/8
#  ⠙ redis [⣿⣿⣿⣿⣀⣿⣿] 36.38MB / 52.42MB Pulling                               4.2s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ⠼ 5c32499ab806 Extracting      1 s                                      1.4s
#    ✔ ebb6b8512082 Download complete                                        0.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ⠼ faa43fe37ea4 Downloading      8.155MB/24.1...                         1.4s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 5/8
#  ⠹ redis [⣿⣿⣿⣿⣤⣿⣿] 42.91MB / 52.42MB Pulling                               4.3s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ⠴ 5c32499ab806 Extracting      1 s                                      1.5s
#    ✔ ebb6b8512082 Download complete                                        0.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ⠴ faa43fe37ea4 Downloading      14.68MB/24.1...                         1.5s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 5/8
#  ⠸ redis [⣿⣿⣿⣿⣶⣿⣿] 48.15MB / 52.42MB Pulling                               4.4s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ⠦ 5c32499ab806 Extracting      1 s                                      1.6s
#    ✔ ebb6b8512082 Download complete                                        0.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ⠦ faa43fe37ea4 Downloading      19.92MB/24.1...                         1.6s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 5/8
#  ⠼ redis [⣿⣿⣿⣿⣿⣿⣿] 52.42MB / 52.42MB Pulling                               4.5s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ⠧ 5c32499ab806 Extracting      1 s                                      1.7s
#    ✔ ebb6b8512082 Download complete                                        0.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ⠧ faa43fe37ea4 Downloading      24.19MB/24.1...                         1.7s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 5/8
#  ⠴ redis [⣿⣿⣿⣿⣿⣿⣿] 52.42MB / 52.42MB Pulling                               4.6s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ⠇ 5c32499ab806 Extracting      1 s                                      1.8s
#    ✔ ebb6b8512082 Download complete                                        0.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ⠇ faa43fe37ea4 Downloading      24.19MB/24.1...                         1.8s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 5/8
#  ⠦ redis [⣿⣿⣿⣿⣿⣿⣿] 52.42MB / 52.42MB Pulling                               4.7s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ⠏ 5c32499ab806 Extracting      1 s                                      1.9s
#    ✔ ebb6b8512082 Download complete                                        0.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ⠏ faa43fe37ea4 Downloading      24.19MB/24.1...                         1.9s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 6/8
#  ⠧ redis [⣿⣿⣿⣿⣿⣿⣿] 52.42MB / 52.42MB Pulling                               4.8s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ⠋ 5c32499ab806 Extracting      1 s                                      2.0s
#    ✔ ebb6b8512082 Download complete                                        0.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ✔ faa43fe37ea4 Download complete                                        1.9s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 6/8
#  ⠇ redis [⣿⣿⣿⣿⣿⣿⣿] 52.42MB / 52.42MB Pulling                               4.9s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ⠙ 5c32499ab806 Extracting      1 s                                      2.1s
#    ✔ ebb6b8512082 Download complete                                        0.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ✔ faa43fe37ea4 Download complete                                        1.9s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 6/8
#  ⠏ redis [⣿⣿⣿⣿⣿⣿⣿] 52.42MB / 52.42MB Pulling                               5.0s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ⠹ 5c32499ab806 Extracting      1 s                                      2.2s
#    ✔ ebb6b8512082 Download complete                                        0.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ✔ faa43fe37ea4 Download complete                                        1.9s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 6/8
#  ⠋ redis [⣿⣿⣿⣿⣿⣿⣿] 52.42MB / 52.42MB Pulling                               5.1s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ⠸ 5c32499ab806 Extracting      1 s                                      2.3s
#    ✔ ebb6b8512082 Download complete                                        0.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ✔ faa43fe37ea4 Download complete                                        1.9s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 6/8
#  ⠙ redis [⣿⣿⣿⣿⣿⣿⣿] 52.42MB / 52.42MB Pulling                               5.2s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ⠼ 5c32499ab806 Extracting      2 s                                      2.4s
#    ✔ ebb6b8512082 Download complete                                        0.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ✔ faa43fe37ea4 Download complete                                        1.9s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 6/8
#  ⠹ redis [⣿⣿⣿⣿⣿⣿⣿] 52.42MB / 52.42MB Pulling                               5.3s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ⠴ 5c32499ab806 Extracting      2 s                                      2.5s
#    ✔ ebb6b8512082 Download complete                                        0.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ✔ faa43fe37ea4 Download complete                                        1.9s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 6/8
#  ⠸ redis [⣿⣿⣿⣿⣿⣿⣿] 52.42MB / 52.42MB Pulling                               5.4s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ⠦ 5c32499ab806 Extracting      2 s                                      2.6s
#    ✔ ebb6b8512082 Download complete                                        0.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ✔ faa43fe37ea4 Download complete                                        1.9s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 6/8
#  ⠼ redis [⣿⣿⣿⣿⣿⣿⣿] 52.42MB / 52.42MB Pulling                               5.5s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ⠧ 5c32499ab806 Extracting      2 s                                      2.7s
#    ✔ ebb6b8512082 Download complete                                        0.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ✔ faa43fe37ea4 Download complete                                        1.9s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 6/8
#  ⠴ redis [⣿⣿⣿⣿⣿⣿⣿] 52.42MB / 52.42MB Pulling                               5.6s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ⠇ 5c32499ab806 Extracting      2 s                                      2.8s
#    ✔ ebb6b8512082 Download complete                                        0.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ✔ faa43fe37ea4 Download complete                                        1.9s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 6/8
#  ⠦ redis [⣿⣿⣿⣿⣿⣿⣿] Pulling                                                 5.7s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ✔ 5c32499ab806 Pull complete                                            2.8s
#    ⠋ ebb6b8512082 Extracting      1 s                                      2.9s
#    ✔ 7555a6149d73 Download complete                                        0.9s
#    ✔ faa43fe37ea4 Download complete                                        1.9s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 6/8
#  ⠧ redis [⣿⣿⣿⣿⣿⣿⣿] 52.42MB / 52.42MB Pulling                               5.8s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ✔ 5c32499ab806 Pull complete                                            2.8s
#    ✔ ebb6b8512082 Pull complete                                            2.9s
#    ✔ 7555a6149d73 Pull complete                                            0.9s
#    ⠋ faa43fe37ea4 Extracting      1 s                                      3.0s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 6/8
#  ⠇ redis [⣿⣿⣿⣿⣿⣿⣿] 52.42MB / 52.42MB Pulling                               5.9s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ✔ 5c32499ab806 Pull complete                                            2.8s
#    ✔ ebb6b8512082 Pull complete                                            2.9s
#    ✔ 7555a6149d73 Pull complete                                            0.9s
#    ⠙ faa43fe37ea4 Extracting      1 s                                      3.1s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 6/8
#  ⠏ redis [⣿⣿⣿⣿⣿⣿⣿] 52.42MB / 52.42MB Pulling                               6.0s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ✔ 5c32499ab806 Pull complete                                            2.8s
#    ✔ ebb6b8512082 Pull complete                                            2.9s
#    ✔ 7555a6149d73 Pull complete                                            0.9s
#    ⠹ faa43fe37ea4 Extracting      1 s                                      3.2s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 6/8
#  ⠋ redis [⣿⣿⣿⣿⣿⣿⣿] 52.42MB / 52.42MB Pulling                               6.1s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ✔ 5c32499ab806 Pull complete                                            2.8s
#    ✔ ebb6b8512082 Pull complete                                            2.9s
#    ✔ 7555a6149d73 Pull complete                                            0.9s
#    ⠸ faa43fe37ea4 Extracting      1 s                                      3.3s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 6/8
#  ⠙ redis [⣿⣿⣿⣿⣿⣿⣿] 52.42MB / 52.42MB Pulling                               6.2s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ✔ 5c32499ab806 Pull complete                                            2.8s
#    ✔ ebb6b8512082 Pull complete                                            2.9s
#    ✔ 7555a6149d73 Pull complete                                            0.9s
#    ⠼ faa43fe37ea4 Extracting      1 s                                      3.4s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 6/8
#  ⠹ redis [⣿⣿⣿⣿⣿⣿⣿] 52.42MB / 52.42MB Pulling                               6.3s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ✔ 5c32499ab806 Pull complete                                            2.8s
#    ✔ ebb6b8512082 Pull complete                                            2.9s
#    ✔ 7555a6149d73 Pull complete                                            0.9s
#    ⠴ faa43fe37ea4 Extracting      1 s                                      3.5s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 6/8
#  ⠸ redis [⣿⣿⣿⣿⣿⣿⣿] 52.42MB / 52.42MB Pulling                               6.4s
#    ✔ 54e1e08620c3 Download complete                                        1.0s
#    ✔ 5c32499ab806 Pull complete                                            2.8s
#    ✔ ebb6b8512082 Pull complete                                            2.9s
#    ✔ 7555a6149d73 Pull complete                                            0.9s
#    ⠦ faa43fe37ea4 Extracting      1 s                                      3.6s
#    ✔ fa3ef5872501 Download complete                                        0.9s
#    ✔ 4f4fb700ef54 Download complete                                        0.3s
# [+] Running 8/8
#  ✔ redis Pulled                                                            6.5s
#    ✔ 54e1e08620c3 Pull complete                                            1.0s
#    ✔ 5c32499ab806 Pull complete                                            2.8s
#    ✔ ebb6b8512082 Pull complete                                            2.9s
#    ✔ 7555a6149d73 Pull complete                                            0.9s
#    ✔ faa43fe37ea4 Pull complete                                            3.6s
#    ✔ fa3ef5872501 Pull complete                                            0.9s
#    ✔ 4f4fb700ef54 Pull complete                                            0.3s
# [+] Running 8/8
#  ✔ redis Pulled                                                            6.5s
#    ✔ 54e1e08620c3 Pull complete                                            1.0s
#    ✔ 5c32499ab806 Pull complete                                            2.8s
#    ✔ ebb6b8512082 Pull complete                                            2.9s
#    ✔ 7555a6149d73 Pull complete                                            0.9s
#    ✔ faa43fe37ea4 Pull complete                                            3.6s
#    ✔ fa3ef5872501 Pull complete                                            0.9s
#    ✔ 4f4fb700ef54 Pull complete                                            0.3s
# [+] Running 0/1
#  ⠋ Network flood-intelligence-network  Creating                            0.0s
# [+] Running 1/1
#  ✔ Network flood-intelligence-network  Created                             0.1s
# [+] Running 2/3
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠋ Container flood-intelligence-redis    Creating                          0.1s
# [+] Running 2/3
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠙ Container flood-intelligence-redis    Creating                          0.2s
# [+] Running 2/3
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠹ Container flood-intelligence-redis    Creating                          0.3s
# [+] Running 2/3
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠸ Container flood-intelligence-redis    Creating                          0.4s
# [+] Running 2/3
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠼ Container flood-intelligence-redis    Creating                          0.5s
# [+] Running 2/3
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠴ Container flood-intelligence-redis    Creating                          0.6s
# [+] Running 2/3
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠦ Container flood-intelligence-redis    Creating                          0.7s
# [+] Running 2/3
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠧ Container flood-intelligence-redis    Creating                          0.8s
# [+] Running 2/3
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠇ Container flood-intelligence-redis    Creating                          0.9s
# [+] Running 2/3
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠏ Container flood-intelligence-redis    Creating                          1.0s
# [+] Running 2/3
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠋ Container flood-intelligence-redis    Creating                          1.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ✔ Container flood-intelligence-redis    Created                           1.2s
#  ⠋ Container flood-intelligence-web      Creating                          0.0s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠙ Container flood-intelligence-redis    Starting                          1.3s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠹ Container flood-intelligence-redis    Starting                          1.4s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠸ Container flood-intelligence-redis    Starting                          1.5s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠼ Container flood-intelligence-redis    Starting                          1.6s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠴ Container flood-intelligence-redis    Waiting                           1.7s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠦ Container flood-intelligence-redis    Waiting                           1.8s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠧ Container flood-intelligence-redis    Waiting                           1.9s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠇ Container flood-intelligence-redis    Waiting                           2.0s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠏ Container flood-intelligence-redis    Waiting                           2.1s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠋ Container flood-intelligence-redis    Waiting                           2.2s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠙ Container flood-intelligence-redis    Waiting                           2.3s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠹ Container flood-intelligence-redis    Waiting                           2.4s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠸ Container flood-intelligence-redis    Waiting                           2.5s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠼ Container flood-intelligence-redis    Waiting                           2.6s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠴ Container flood-intelligence-redis    Waiting                           2.7s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠦ Container flood-intelligence-redis    Waiting                           2.8s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠧ Container flood-intelligence-redis    Waiting                           2.9s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠇ Container flood-intelligence-redis    Waiting                           3.0s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠏ Container flood-intelligence-redis    Waiting                           3.1s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠋ Container flood-intelligence-redis    Waiting                           3.2s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠙ Container flood-intelligence-redis    Waiting                           3.3s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠹ Container flood-intelligence-redis    Waiting                           3.4s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠸ Container flood-intelligence-redis    Waiting                           3.5s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠼ Container flood-intelligence-redis    Waiting                           3.6s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠴ Container flood-intelligence-redis    Waiting                           3.7s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠦ Container flood-intelligence-redis    Waiting                           3.8s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠧ Container flood-intelligence-redis    Waiting                           3.9s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠇ Container flood-intelligence-redis    Waiting                           4.0s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠏ Container flood-intelligence-redis    Waiting                           4.1s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠋ Container flood-intelligence-redis    Waiting                           4.2s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠙ Container flood-intelligence-redis    Waiting                           4.3s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠹ Container flood-intelligence-redis    Waiting                           4.4s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠸ Container flood-intelligence-redis    Waiting                           4.5s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠼ Container flood-intelligence-redis    Waiting                           4.6s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠴ Container flood-intelligence-redis    Waiting                           4.7s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠦ Container flood-intelligence-redis    Waiting                           4.8s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠧ Container flood-intelligence-redis    Waiting                           4.9s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠇ Container flood-intelligence-redis    Waiting                           5.0s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠏ Container flood-intelligence-redis    Waiting                           5.1s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠋ Container flood-intelligence-redis    Waiting                           5.2s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠙ Container flood-intelligence-redis    Waiting                           5.3s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠹ Container flood-intelligence-redis    Waiting                           5.4s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠸ Container flood-intelligence-redis    Waiting                           5.5s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠼ Container flood-intelligence-redis    Waiting                           5.6s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠴ Container flood-intelligence-redis    Waiting                           5.7s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠦ Container flood-intelligence-redis    Waiting                           5.8s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠧ Container flood-intelligence-redis    Waiting                           5.9s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠇ Container flood-intelligence-redis    Waiting                           6.0s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠏ Container flood-intelligence-redis    Waiting                           6.1s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠋ Container flood-intelligence-redis    Waiting                           6.2s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠙ Container flood-intelligence-redis    Waiting                           6.3s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠹ Container flood-intelligence-redis    Waiting                           6.4s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠸ Container flood-intelligence-redis    Waiting                           6.5s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠼ Container flood-intelligence-redis    Waiting                           6.6s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠴ Container flood-intelligence-redis    Waiting                           6.7s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠦ Container flood-intelligence-redis    Waiting                           6.8s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠧ Container flood-intelligence-redis    Waiting                           6.9s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠇ Container flood-intelligence-redis    Waiting                           7.0s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ⠏ Container flood-intelligence-redis    Waiting                           7.1s
#  ✔ Container flood-intelligence-web      Created                           0.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ✔ Container flood-intelligence-redis    Healthy                           7.1s
#  ⠙ Container flood-intelligence-web      Starting                          6.0s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ✔ Container flood-intelligence-redis    Healthy                           7.1s
#  ⠹ Container flood-intelligence-web      Starting                          6.1s
# [+] Running 3/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ✔ Container flood-intelligence-redis    Healthy                           7.1s
#  ⠸ Container flood-intelligence-web      Starting                          6.2s
# [+] Running 4/4
#  ✔ Network flood-intelligence-network    Created                           0.1s
#  ✔ Volume flood-intelligence-redis-data  Created                           0.0s
#  ✔ Container flood-intelligence-redis    Healthy                           7.1s
#  ✔ Container flood-intelligence-web      Started                           6.3s

# %% [markdown]
# ### Wait for all containers to be healthy

# %%
# Check the status of the deployed containers. Wait till the STATUS is healthy

# !docker ps -a
# Out:
# CONTAINER ID   IMAGE                                             COMMAND                  CREATED              STATUS                        PORTS                    NAMES
# ba536893d597   h2oairelease/h2oai-floodintelligence-app:v1.2.0   "./docker-entrypoint…"   About a minute ago   Up 59 seconds (healthy)       0.0.0.0:8090->8000/tcp   flood-intelligence-web
# 9bcd8f40613c   redis:8.2.1                                       "docker-entrypoint.s…"   About a minute ago   Up About a minute (healthy)   6379/tcp                 flood-intelligence-redis

# %% [markdown]
# ### Imports

# %%
import json
import os
import time

import pandas as pd
import requests

from openai import OpenAI

# %% [markdown]
# ### Helper Functions

# %%
def preview_key(value: str) -> str:
    if not value:
        return "Not set"
    if len(value) <= 14:
        return f"{value[:4]}{'.' * len(value) - 4}"
    dots = max(1, len(value) - 14)
    return f"{value[:10]}{'.' * dots}{value[-4:]}"


def check_service(base_url, path, name, headers=None):
    url = f"{base_url}/{path.lstrip('/')}"
    try:
        response = requests.get(url, headers=headers, timeout=10)
    except requests.exceptions.RequestException as exc:
        print(f"❌ {name} is not responding: {exc}")
        return False

    if response.status_code == 200:
        print(f"✅ {name} is running")
        return True
    if response.status_code == 401:
        print(f"⚠️  {name} requires authentication (401)")
        return True

    print(f"⚠️  {name} responded with status {response.status_code}")
    return False

# %% [markdown]
# ### Verify API Keys

# %%
NVIDIA_API_KEY = os.getenv("NVIDIA_API_KEY")
if NVIDIA_API_KEY:
    print(f"✅ NVIDIA_API_KEY: {preview_key(NVIDIA_API_KEY)}")
else:
    print("❗ NVIDIA_API_KEY NOT SET")

H2OGPTE_URL = os.getenv("H2OGPTE_URL")
if H2OGPTE_URL:
    print(f"✅ H2OGPTE_URL: {H2OGPTE_URL}")
else:
    print("⚠️ H2OGPTE_URL NOT SET")

H2OGPTE_API_KEY = os.getenv("H2OGPTE_API_KEY")
if H2OGPTE_API_KEY:
    print(f"✅ H2OGPTE_API_KEY: {preview_key(H2OGPTE_API_KEY)}")
else:
    print("⚠️ H2OGPTE_API_KEY NOT SET")

if H2OGPTE_URL and H2OGPTE_API_KEY:
    print("✅ h2oGPTe credentials found")
    H2OGPTE_AVAILABLE = True
else:
    print("⚠️  h2oGPTe credentials not set")
    print("Please get h2oGPTe credentials and restart the notebook from the start.")
    H2OGPTE_AVAILABLE = False

api_port = os.getenv("WEB_PORT")
if not api_port:
    print("⚠️ WEB_PORT not set. API interactions will be skipped.")

api_server_base_url = os.getenv("API_SERVER_URL", f"http://localhost:{api_port}")
if api_port and api_server_base_url:
    print(f"✅ API_SERVER_URL detected: {api_server_base_url}")
else:
    print("⚠️ API_SERVER_URL not set. API interactions will be skipped.")

# Set this to False Here.
# Later, we will verify that a Local NIM LLM is deployed and is reachable. If yes, we will set this to True
LOCAL_NIM_AVAILABLE = False
# Out:
# ✅ NVIDIA_API_KEY: nvapi-Ztxr........................................................DVnK
# ✅ H2OGPTE_URL: https://h2ogpte.genai.h2o.ai/
# ✅ H2OGPTE_API_KEY: sk-Tnro3Qk.....................................Bf9s
# ✅ h2oGPTe credentials found
# ✅ API_SERVER_URL detected: http://localhost:8090

# %%
if not api_server_base_url:
    print("⚠️  API_SERVER_URL not set. Export API_SERVER_URL before continuing.")
else:
    base_url = api_server_base_url.rstrip("/")
    print("📍 Service Endpoints:")
    print(f"   - FastAPI Server: {base_url}")
    print(f"   - API Docs: {base_url}/docs")
    print(f"   - Agents API: {base_url}/api/agents")
    print("\nUse the next cell to verify service health.")
# Out:
# 📍 Service Endpoints:
#    - FastAPI Server: http://localhost:8090
#    - API Docs: http://localhost:8090/docs
#    - Agents API: http://localhost:8090/api/agents
#
# Use the next cell to verify service health.

# %% [markdown]
# ### ✅ Verify Services
#
# Let's check that all services are running correctly:

# %%
print("🔍 Checking service health...\n")

if not api_server_base_url:
    print("⚠️  API_SERVER_URL not set. Skipping health checks.")
    fastapi_ok = False
else:
    base_url = api_server_base_url.rstrip("/")

    fastapi_ok = check_service(
        base_url,
        "api/dashboard",
        "FastAPI Dashboard",
    )
    agents_ok = check_service(
        base_url,
        "api/agents",
        "Agents API",
        headers={"Authorization": "Bearer local-token"},
    )
    watersheds_ok = check_service(
        base_url,
        "api/watersheds",
        "Watersheds API",
    )

    print("\n" + "=" * 50)
    if fastapi_ok and agents_ok and watersheds_ok:
        print("✅ All services are responding!")
    else:
        print("⚠️  One or more endpoints did not respond as expected.")
        print("Review Helm deployment status or API logs if needed.")
    print("=" * 50)
# Out:
# 🔍 Checking service health...
#
# ✅ FastAPI Dashboard is running
# ✅ Agents API is running
# ✅ Watersheds API is running
#
# ==================================================
# ✅ All services are responding!
# ==================================================

# %% [markdown]
# ### Verify that a Local NIM LLM is deployed and is reachable

# %%
# Set the base url for NIM
nimllm_port = os.getenv("NIMLLM_PORT", "8989")
nim_llm_base_url = f"http://localhost:{nimllm_port}/v1"
print(f"If Local NIM LLM is running, it will be available at: {nim_llm_base_url}")
# Out:
# If Local NIM LLM is running, it will be available at: http://localhost:8989/v1

# %%
# Test if the NIM container is up. This will take 15 to 30 mins. Repeat this step until you see a positive message.
if nim_llm_base_url:
    try:
        response = requests.get(f"{nim_llm_base_url}/models", timeout=10)
        if response.status_code == 200:
            print("✅ Local NIM LLM is running")
            LOCAL_NIM_AVAILABLE = True
        else:
            print("⚠️ No locally deployed NIM LLM is found. Will be using NIMs via API.")
    except Exception as e:
        print("⚠️ No locally deployed NIM LLM is found. Will be using NIMs via API.")
else:
    print("⚠️ No locally deployed NIM LLM is found. Will be using NIMs via API.")
# Out:
# ⚠️ No locally deployed NIM LLM is found. Will be using NIMs via API.

# %% [markdown]
# ---
#
# # Section 2: NVIDIA NIM Integration
#
# ## 🚀 NVIDIA NIM - Optimized Inference Microservices
#
# NVIDIA NIM provides high-performance inference for state-of-the-art language models. Our flood intelligence system uses several NVIDIA models:
#
# ### Available Models
#
# 1. **nvidia/llama-3.3-nemotron-super-49b-v1.5** (Default)
#    - Latest Nemotron model optimized for instruction following
#    - Excellent for agent workflows and tool calling
#    - 49B parameters with superior efficiency
#
# 2. **meta/llama-3.1-70b-instruct**
#    - Strong general-purpose reasoning
#    - Great for complex analysis tasks
#
# ### Let's test NVIDIA NIM integration:

# %%
# Initialize NVIDIA NIM client
# If LOCAL_NIM_AVAILABLE is True, it will be preferred. Please modify this cell to use external NVIDIA API.

USE_NVIDIA_API = False

if LOCAL_NIM_AVAILABLE:
    print(f"Using local NIM LLM base URL: {nim_llm_base_url}")
    model = "nvidia/llama-3_3-nemotron-super-49b-v1_5"
    client = OpenAI(
        base_url=nim_llm_base_url,
        api_key="no-key",
    )
else:
    USE_NVIDIA_API = True

    # Test with Nemotron Super 49B
    model = "nvidia/llama-3.3-nemotron-super-49b-v1.5"

    # From Nvidia API
    client = OpenAI(
        base_url="https://integrate.api.nvidia.com/v1",
        api_key=NVIDIA_API_KEY,
    )

# %%
print(f"🤖 Testing NVIDIA NIM with {model}\n")

response = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": "You are an expert flood prediction assistant."},
        {
            "role": "user",
            "content": "What are the key factors that indicate an increased risk of flooding in a river basin?",
        },
    ],
    temperature=0.7,
    max_tokens=500,
)

print("📝 Response:")
print(response.choices[0].message.content)
print(f"\n📊 Tokens used: {response.usage.total_tokens}")
# Out:
# 🤖 Testing NVIDIA NIM with nvidia/llama-3.3-nemotron-super-49b-v1.5
#
# 📝 Response:
# <think>
# Okay, so I need to figure out the key factors that indicate an increased risk of flooding in a river basin. Let me start by recalling what I know about floods and river basins. A river basin is the area of land that drains water into a particular river and its tributaries. Flooding happens when the river can't hold the amount of water it's receiving, right?
#
# First, I think about precipitation. If there's a lot of rain, especially heavy or prolonged rainfall, that should contribute to flooding. But how much exactly? Maybe the intensity and duration of rainfall are important. Also, snowmelt could be a factor in some regions. If the snow melts quickly, that adds a lot of water to the river system.
#
# Then there's the land use in the basin. If the area is urbanized with lots of concrete and asphalt, water can't soak into the ground, so it runs off more quickly into the rivers. That could lead to faster rising water levels. Conversely, areas with lots of vegetation or wetlands might absorb more water, reducing flood risk. So land cover and land use changes like deforestation or urbanization might be factors.
#
# Soil type and saturation also come to mind. If the soil is already saturated from previous rain, any additional rain can't be absorbed and just runs off, increasing flood risk. Different soils have different permeability; sandy soils drain faster than clay, so clay-heavy areas might hold more water.
#
# The topography of the basin matters too. Steeper slopes would mean water flows faster into the river, which might lead to quicker but maybe shorter-lived floods. Flatter areas might take longer to flood but could have more widespread flooding. The shape and size of the basin itself—if it's a large basin, maybe it can handle more water, but if it's small and steep, the response could be quicker.
#
# River channel characteristics: if the river is narrow or has obstacles like bridges or dams, the flow could be restricted, causing water to back up and flood. Also, if the river is already at a high level, even a little more water can cause overtopping. Channelization or straightening of rivers might increase flow speed but reduce the area available for water storage.
#
# Human infrastructure like dams and reservoirs. Dams can control water flow, so if they're managed properly, they might reduce flood risk. But if they fail or if there's too much water, they could release large amounts
#
# 📊 Tokens used: 540

# %% [markdown]
# ### Streaming Response Example
#
# NVIDIA NIM supports streaming for real-time responses:

# %%
print("🌊 Streaming response about flood intelligence...\n")

stream = client.chat.completions.create(
    model=model,
    messages=[
        {"role": "system", "content": "You are a concise flood intelligence expert."},
        {
            "role": "user",
            "content": "Explain how AI can improve flood forecasting accuracy.",
        },
    ],
    temperature=0.7,
    max_tokens=300,
    stream=True,
)

for chunk in stream:
    if chunk.choices[0].delta.content is not None:
        print(chunk.choices[0].delta.content, end="", flush=True)

print("\n\n✅ Streaming complete!")
# Out:
# 🌊 Streaming response about flood intelligence...
#
# <think>
# Okay, the user wants to know how AI can improve flood forecasting accuracy. Let me start by recalling what I know about flood forecasting and AI applications. Flood forecasting traditionally uses hydrological models that rely on data like rainfall, river levels, soil moisture, etc. These models might have limitations in handling complex, non-linear relationships or large datasets.
#
# AI, especially machine learning and deep learning, can process vast amounts of data and detect patterns that traditional models might miss. So, how exactly does that work? Maybe AI can integrate various data sources more effectively. For example, combining satellite imagery, real-time sensor data, weather forecasts, and social media reports. That could provide a more comprehensive input for predictions.
#
# Then there's the aspect of handling uncertainty. Traditional models might struggle with uncertain or incomplete data. AI models, particularly those using probabilistic approaches or ensemble methods, might better quantify uncertainty, giving more reliable confidence intervals for flood predictions.
#
# Another point is the spatial and temporal resolution. AI can downscale large-scale weather models to local levels, improving the granularity of forecasts. Techniques like convolutional neural networks (CNNs) might analyze satellite images to detect early signs of flooding, like rising water levels in specific areas.
#
# Real-time data processing is another area. AI can analyze data streams from IoT sensors and adjust forecasts dynamically. This real-time adaptation could reduce the time between prediction and actual event, giving more lead time for evacuations.
#
# Also, AI can optimize existing models. By training on historical
#
# ✅ Streaming complete!

# %% [markdown]
# ### Model Comparison
#
# Let's compare responses from different NVIDIA models:

# %%
if USE_NVIDIA_API:
    models_to_test = [
        "nvidia/llama-3.3-nemotron-super-49b-v1.5",
        "meta/llama-3.1-70b-instruct",
    ]
else:
    models_to_test = [model]

question = "Given streamflow of 2500 CFS and rising 200 CFS/hour, should we issue a flood alert?"

print(f"📊 Comparing model responses for:\n'{question}'\n")
print("=" * 80)

for model_name in models_to_test:
    print(f"\n🤖 Model: {model_name.split('/')[-1]}\n")

    try:
        response = client.chat.completions.create(
            model=model_name,
            messages=[
                {
                    "role": "system",
                    "content": "You are a flood emergency expert. Be concise.",
                },
                {"role": "user", "content": question},
            ],
            temperature=0.3,
            max_tokens=200,
        )

        print(response.choices[0].message.content)
        print(f"\n📈 Tokens: {response.usage.total_tokens}")

    except Exception as e:
        print(f"❌ Error: {e}")

    print("\n" + "-" * 80)
# Out:
# 📊 Comparing model responses for:
# 'Given streamflow of 2500 CFS and rising 200 CFS/hour, should we issue a flood alert?'
#
# ================================================================================
#
# 🤖 Model: llama-3.3-nemotron-super-49b-v1.5
#
# <think>
# Okay, let's see. The user is asking if they should issue a flood alert given a streamflow of 2500 CFS that's rising at 200 CFS per hour. Hmm, first, I need to recall what factors are involved in determining a flood alert.
#
# Streamflow is measured in cubic feet per second (CFS), which indicates the volume of water passing a point. The rate of rise is also important because a rapid increase can lead to flooding even if the current flow isn't at flood stage yet. But what's the threshold for issuing an alert?
#
# I think flood alerts are typically based on specific thresholds set by local authorities or agencies like the National Weather Service (NWS) in the US. These thresholds vary depending on the river, location, and historical data. Without knowing the specific flood stage for this particular stream or river, it's hard to say definitively.
#
# Wait, but maybe there's a general guideline. For example, if the stream
#
# 📈 Tokens: 250
#
# --------------------------------------------------------------------------------
#
# 🤖 Model: llama-3.1-70b-instruct
#
# Streamflow is already high (2500 CFS) and rising rapidly (200 CFS/hour). I recommend issuing a flood alert immediately. The rapid increase in streamflow indicates a high risk of flooding, and prompt action is necessary to protect people and property.
#
# 📈 Tokens: 103
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ### LLM-as-Judge Evaluation
#
# The system includes an automatic evaluation feature using **cross-provider LLM-as-Judge**:
# - When NVIDIA models generate responses, h2oGPTe judges them
# - When h2oGPTe generates responses, NVIDIA models judge them
# - This provides unbiased evaluation of response quality
#
# Let's evaluate the NVIDIA model responses using our evaluation API:

# %%
# Let's evaluate one of the model responses from above
question = "Given streamflow of 2500 CFS and rising 200 CFS/hour, should we issue a flood alert?"

# Response from meta/llama-3.1-70b-instruct (from cell 12)
response_text = """Streamflow is already high (2500 CFS) and rising rapidly (200 CFS/hour). I recommend issuing a flood alert immediately. The rapid increase in streamflow indicates a high risk of flooding, and prompt action is necessary to protect people and property."""

print("🔍 Evaluating NVIDIA model response using LLM-as-Judge...\n")

# Call the evaluation API
eval_payload = {
    "question": question,
    "response": response_text,
    "model": "meta/llama-3.1-70b-instruct",
    "agent_used": False,
    "response_provider": "nvidia",  # This will trigger h2oGPTe as the judge
}

headers = {"Authorization": "Bearer local-token"}
response = requests.post(
    f"{api_server_base_url}/api/evaluation/evaluate", json=eval_payload, headers=headers
)

if response.status_code == 200:
    eval_result = response.json()

    print("✅ Evaluation Complete!\n")
    print("=" * 80)
    print("📊 Evaluation Metrics:\n")

    metrics = eval_result.get("metrics", {})
    print(f"   🎯 Overall Score:    {metrics.get('overall', 0):.1f}/10")
    print(f"   🤝 Helpfulness:      {metrics.get('helpfulness', 0):.1f}/10")
    print(f"   ✅ Accuracy:         {metrics.get('accuracy', 0):.1f}/10")
    print(f"   🎯 Relevance:        {metrics.get('relevance', 0):.1f}/10")
    print(f"   📝 Coherence:        {metrics.get('coherence', 0):.1f}/10")
    print(f"   🛡️  Safety:           {metrics.get('safety', 0):.1f}/10")
    print(f"   💪 Confidence:       {metrics.get('confidence', 0):.1%}")

    print("\n💭 Judge's Reasoning:")
    print(f"   {eval_result.get('reasoning', 'N/A')}")

    print(f"\n⏱️  Evaluation Duration: {eval_result.get('duration_ms', 0)}ms")
    print(f"🆔 Evaluation ID: {eval_result.get('evaluation_id', 'N/A')}")
    print("=" * 80)
else:
    print(f"❌ Error: {response.status_code}")
    print(response.text)
# Out:
# 🔍 Evaluating NVIDIA model response using LLM-as-Judge...
#
# ✅ Evaluation Complete!
#
# ================================================================================
# 📊 Evaluation Metrics:
#
#    🎯 Overall Score:    6.0/10
#    🤝 Helpfulness:      6.5/10
#    ✅ Accuracy:         4.0/10
#    🎯 Relevance:        8.0/10
#    📝 Coherence:        9.0/10
#    🛡️  Safety:           7.0/10
#    💪 Confidence:       75.0%
#
# 💭 Judge's Reasoning:
#    The response is clear and directly addresses the question about issuing a flood alert. However, it lacks critical context needed for accurate flood prediction: no mention of the watershed size, local flood stage thresholds, basin characteristics, or historical context for what constitutes dangerous flow in this specific location. While recommending caution is appropriate, making a definitive recommendation without this context reduces accuracy. The response is well-structured and easy to understand, but should have acknowledged the information gaps and suggested additional factors to consider before making a final decision. Without knowing the specific river/stream's flood stage thresholds, a blanket recommendation to issue an alert may be premature or delayed depending on local conditions.
#
# ⏱️  Evaluation Duration: 8143ms
# 🆔 Evaluation ID: f09ebeb1-5d51-4b08-aaa4-245379fb788a
# ================================================================================

# %% [markdown]
# ---
#
# # Section 3: h2oGPTe Agent (A2A) Integration
#
# ## 🧠 h2oGPTe - Enterprise AI with Agent Mode
#
# h2oGPTe provides advanced AutoML capabilities through its agent mode, enabling:
#
# - **Driverless AI Integration**: Automated machine learning with minimal code
# - **Agent-to-Agent (A2A)**: AI agents that can invoke other AI agents
# - **Feature Engineering**: Automatic feature creation for time-series data
# - **Model Interpretability**: Explainable AI for emergency response decisions
#
# ### Setting up h2oGPTe Client
#
# **Note**: This section requires h2oGPTe credentials. If you don't have access, you can skip to the next section.
#
# Get your credentials at: [H2O.ai Enterprise](https://h2o.ai/platform/enterprise-h2ogpte/)

# %% [markdown]
# ### h2oGPTe for Flood Prediction ML
#
# Let's use h2oGPTe's agent mode to get guidance on training a flood prediction model:

# %%
if H2OGPTE_AVAILABLE:
    headers = {"Authorization": "Bearer local-token"}
    # Using FastAPI streaming endpoint for h2oGPTe
    url = f"{api_server_base_url}/api/ai/chat/enhanced/stream"

    payload = {
        "message": """I have flood prediction data with these features:
        - streamflow_cfs: Current river flow rate
        - rainfall_24h: Rainfall in last 24 hours
        - river_stage_ft: Water level
        - soil_moisture: Ground saturation
        - elevation_ft: Location elevation

        How should I approach building an ML model to predict flood risk in the next 24 hours?
        What feature engineering would you recommend?""",
        "provider": "h2ogpte",
        "use_agent": True,
        "max_tokens": 8192 * 10,
    }

    print("🧠 Consulting h2oGPTe agent for AutoML guidance...\n")

    response = requests.post(url, json=payload, headers=headers, stream=True)

    if response.status_code == 200:
        last_content = ""
        # Stream the response
        for line in response.iter_lines():
            if line:
                line_str = line.decode("utf-8")
                if line_str.startswith("data: "):
                    data_str = line_str[6:]  # Remove 'data: ' prefix
                    try:
                        data = json.loads(data_str)

                        # First message contains provider info
                        if "provider" in data:
                            print(f"📡 Provider: {data.get('provider')}")
                            print(f"🤖 Model: {data.get('model')}\n")
                            print("📝 Response:\n")

                        # h2oGPTe sends incremental chunks with full content
                        elif "chunk" in data and not data.get("done", False):
                            new_content = data["chunk"]
                            # Only print the new portion
                            if new_content.startswith(last_content):
                                new_part = new_content[len(last_content) :]
                                print(new_part, end="", flush=True)
                                last_content = new_content

                        # Check for completion
                        elif data.get("done", False):
                            break

                    except json.JSONDecodeError:
                        pass

        print("\n\n✅ Streaming complete!")
    else:
        print(f"❌ Error: {response.status_code}")
        print(response.text)
else:
    print("⏭️  Skipping h2oGPTe demo (credentials not available)")
# Out:
# 🧠 Consulting h2oGPTe agent for AutoML guidance...
#
# 📡 Provider: h2ogpte
# 🤖 Model: claude-3-7-sonnet-20250219
#
# 📝 Response:
#
# #### Agentic Analysis
# #### Starting Agent
#
#
# ✅ Streaming complete!

# %% [markdown]
# ---
#
# # Section 4: Multi-Agent System with FastMCP
#
# ## 🤝 FastMCP - Model Context Protocol Server
#
# Our flood intelligence system uses FastMCP to expose 20+ specialized tools across 5 intelligent agents:
#
# ### The 5 Agents
#
# 1. **Data Collector Agent** 📊
#    - Collects USGS water data
#    - Retrieves NOAA flood forecasts
#    - Gathers weather information
#    - Monitors data quality
#
# 2. **Risk Analyzer Agent** ⚠️
#    - Calculates flood risk scores
#    - Analyzes trends and patterns
#    - Identifies high-risk areas
#
# 3. **Emergency Responder Agent** 🚨
#    - Assesses emergency readiness
#    - Activates alerts
#    - Coordinates evacuations
#
# 4. **AI Predictor Agent** 🔮
#    - Generates flood forecasts
#    - Predicts critical conditions
#    - Analyzes prediction accuracy
#
# 5. **H2OGPTE ML Agent** 🧠
#    - Trains ML models
#    - Optimizes features
#    - Analyzes model performance
#
# ### Let's explore the available tools:

# %%
# Get list of all agents and their capabilities
response = requests.get(f"{api_server_base_url}/api/agents")

if response.status_code == 200:
    data = response.json()

    print("🤖 Available Agents and Their Status\n")
    print("=" * 80)

    # The API returns a nested structure with agents dictionary
    agents_dict = data.get("agents", {})

    for agent_key, agent_data in agents_dict.items():
        status = "🟢" if agent_data.get("is_running") else "🔴"
        print(f"\n{status} {agent_data.get('name', agent_key)}")
        print(f"   Description: {agent_data.get('description', 'N/A')}")
        print(f"   Status: {'Running' if agent_data.get('is_running') else 'Stopped'}")
        if agent_data.get("last_check"):
            print(f"   Last Check: {agent_data.get('last_check')}")
        if agent_data.get("check_interval"):
            print(f"   Check Interval: {agent_data.get('check_interval')} seconds")
        if agent_data.get("insights_count"):
            print(f"   Insights: {agent_data.get('insights_count')}")
        if agent_data.get("active_alerts_count"):
            print(f"   Active Alerts: {agent_data.get('active_alerts_count')}")

    print("\n" + "=" * 80)
else:
    print(f"❌ Error fetching agents: {response.status_code}")
# Out:
# 🤖 Available Agents and Their Status
#
# ================================================================================
#
# 🟢 Data Collector
#    Description: Continuously pulls real-time flood data from USGS, NOAA, and weather APIs
#    Status: Running
#    Last Check: 2025-11-14T08:11:43.379414+00:00
#    Check Interval: 300 seconds
#    Insights: 4
#
# 🟢 Risk Analyzer
#    Description: AI-powered analysis of flood risk conditions and trend detection
#    Status: Running
#    Last Check: 2025-11-14T08:11:43.379619+00:00
#    Check Interval: 600 seconds
#    Insights: 4
#    Active Alerts: 1
#
# 🟢 Emergency Responder
#    Description: Coordinates emergency response activities and manages critical alerts
#    Status: Running
#    Last Check: 2025-11-14T08:14:36.435686+00:00
#    Check Interval: 180 seconds
#    Insights: 5
#    Active Alerts: 2
#
# 🟢 AI Predictor
#    Description: Advanced AI forecasting and predictive analysis for flood conditions
#    Status: Running
#    Last Check: 2025-11-14T08:11:43.380009+00:00
#    Check Interval: 900 seconds
#    Insights: 4
#
# ================================================================================

# %% [markdown]
# ### View Agent Insights
#
# Agents continuously monitor flood conditions and generate insights:

# %%
# Refresh USGS data before getting insights
print("🔄 Refreshing USGS data first...\n")

# Note: Using local-token for development mode (server.py allows this when OIDC is disabled)
headers = {"Authorization": "Bearer local-token"}

refresh_response = requests.post(
    f"{api_server_base_url}/api/dashboard/refresh-usgs-data", headers=headers
)

if refresh_response.status_code == 200:
    refresh_result = refresh_response.json()
    print(f"✅ {refresh_result.get('message', 'Data refresh initiated')}")

    # Wait a moment for background job to start
    print("⏳ Waiting for data refresh to process...\n")
    time.sleep(3)
else:
    print(f"⚠️  Data refresh returned status {refresh_response.status_code}")
    print("   Proceeding with existing data...\n")

# Get insights from all agents
response = requests.get(f"{api_server_base_url}/api/agents/insights")

if response.status_code == 200:
    data = response.json()

    print("💡 Agent Insights\n")
    print("=" * 80)

    # The API returns insights grouped by agent
    insights_by_agent = data.get("insights", {})

    count = 0
    for agent_name, agent_insights in insights_by_agent.items():
        print(f"\n🤖 {agent_name.replace('_', ' ').title()}")
        print("-" * 60)

        for insight in agent_insights:
            title = insight.get("title", "N/A")
            value = insight.get("value", "N/A")
            change = insight.get("change")
            urgency = insight.get("urgency", "normal")
            timestamp = insight.get("timestamp", "")

            urgency_icon = {
                "critical": "🔴",
                "high": "🟡",
                "normal": "🔵",
                "low": "🟢",
            }.get(urgency, "⚪")

            print(f"\n{urgency_icon} {title}: {value}")
            if change:
                print(f"   Change: {change}")

            count += 1
            if count >= 15:  # Limit total insights shown
                break

        if count >= 15:
            break

    print("\n" + "=" * 80)
    print(f"Generated at: {data.get('generated_at', 'N/A')}")
else:
    print(f"❌ Error fetching insights: {response.status_code}")
# Out:
# 🔄 Refreshing USGS data first...
#
# ⚠️  Data refresh returned status 500
#    Proceeding with existing data...
#
# 💡 Agent Insights
#
# ================================================================================
#
# 🤖 Data Collector
# ------------------------------------------------------------
#
# 🔵 🔄 Data Freshness: 100% current
#
# 🔵 🌐 API Connectivity: 5/5 active
#
# 🔵 📊 Data Quality: 9.3/10
#    Change: +0.0
#
# 🔵 ⚡ Update Frequency: 12 updates/hour
#
# 🤖 Risk Analyzer
# ------------------------------------------------------------
#
# 🔵 🎯 Overall Risk Level: MODERATE (5.0/10)
#    Change: +0.0
#
# 🔵 🚨 Critical Watersheds: 1 areas
#
# 🔵 📈 Risk Trend Analysis: Stable
#    Change: 0.0% per hour
#
# 🔵 🧠 AI Confidence: 0%
#    Change: Low
#
# 🤖 Emergency Responder
# ------------------------------------------------------------
#
# 🔵 🚨 Active Incidents: 0 ongoing
#
# 🔵 🚁 Response Readiness: GOOD (85%)
#    Change: 8 teams ready
#
# 🔵 🏃 Evacuation Status: No active evacuations
#    Change: 0 zones active
#
# 🔵 📡 Communication Systems: 100% operational
#    Change: 6 channels active
#
# 🔵 📢 Alert Distribution: 0 alerts sent
#    Change: 0 today
#
# 🤖 Predictor
# ------------------------------------------------------------
#
# 🔵 🎯 Model Accuracy: 85.0%
#    Change: +0.0% vs yesterday
#
# 🔵 🧠 Prediction Confidence: 72%
#    Change: High
#
# ================================================================================
# Generated at: 2025-11-14T08:16:19.033329+00:00

# %% [markdown]
# ### Example 1: Risk Analyzer Agent
#
# Calculates comprehensive flood risk scores:

# %%
# Run Risk Analyzer Agent via NAT
payload = {
    "agent": "risk_analyzer",
    "message": """Analyze current flood risk for the Texas:
    1. Calculate detailed risk scores for all factors
    2. Identify the highest risk components
    3. Provide trend analysis
    4. Give recommendations for monitoring

    Be specific about the risk levels and factors.""",
}

print("Running Risk Analyzer Agent...\n")

headers = {"Authorization": "Bearer local-token"}

response = requests.post(
    f"{api_server_base_url}/api/nat/chat/stream",
    json=payload,
    headers=headers,
    stream=True,
)

if response.status_code == 200:
    final_output = None

    for line in response.iter_lines():
        if line:
            line_str = line.decode("utf-8")
            if line_str.startswith("data: "):
                data_str = line_str[6:]  # Remove 'data: ' prefix
                try:
                    data = json.loads(data_str)

                    # Handle different event types
                    event_type = data.get("type")

                    if event_type == "start":
                        print(f"🚀 Starting {data.get('agent_type')} agent...")
                        print()

                    elif event_type == "log":
                        log_entry = data.get("log", {})
                        level = log_entry.get("level", "INFO")
                        message = log_entry.get("message", "")

                        # Show important logs
                        if level in ["WARNING", "ERROR"]:
                            print(f"[{level}] {message}")
                        elif (
                            "Agent" in message
                            or "Final Answer" in message
                            or "Tool" in message
                        ):
                            print(f"💬 {message}")

                    elif event_type == "result":
                        final_output = data.get("output")
                        print("\n" + "=" * 80)
                        print("✅ Data Collection Complete!\n")

                    elif event_type == "error":
                        print(f"\n❌ Error: {data.get('error')}")

                    elif event_type == "done":
                        break

                except json.JSONDecodeError:
                    pass

    # Display final output
    if final_output:
        print(final_output)
        print("=" * 80)
else:
    print(f"❌ Error: {response.status_code}")
    print(response.text)
# Out:
# Running Risk Analyzer Agent...
#
# 🚀 Starting risk_analyzer agent...
#
# [WARNING] Using provided input_schema for multi-argument function
# [WARNING] Using provided input_schema for multi-argument function
# [WARNING] Using provided input_schema for multi-argument function
# 💬
# ------------------------------
# [AGENT]
# Agent input: Analyze current flood risk for the Texas:
#     1. Calculate detailed risk scores for all factors
#     2. Identify the highest risk components
#     3. Provide trend analysis
#     4. Give recommendations for monitoring
#
#     Be specific about the risk levels and factors.
# Agent's thoughts:
# k>
#
# Action: comprehensive_flood_analysis_tool
# Action Input: {"location": "Texas"}
#
#
# ------------------------------
# 💬
# ------------------------------
# [AGENT]
# Calling tools: comprehensive_flood_analysis_tool
# Tool's input: {'location': 'Texas'}
# Tool's response:
# {"status":"success","location":"Texas","analysis_timestamp":"2025-11-14T08:16:53.268840+00:00","data_collection":{"agent":"Data Collector","data_sources":{"usgs_sites":10,"noaa_alerts":0,"weather_locations":7},"insights":[{"title":"🔄 Data Freshness","value":"100% current","trend":"up","urgency":"normal"},{"title":"🌐 API Connectivity","value":"5/5 active","trend":"up","urgency":"normal"},{"title":"📊 Data Quality","value":"9.3/10","trend":"up","urgency":"normal"},{"title":"⚡ Update Frequency","value":"12 updates/hour","trend":"stable","urgency":"normal"}],"alerts":[]},"risk_analysis":{"agent":"Risk Analyzer","insights":[{"title":"🎯 Overall Risk Level","value":"Unknown (0.0/10)","trend":"stable","urgency":"normal"},{"title":"🚨 Critical Watersheds","value":"0 areas","trend":"stable","urgency":"normal"},{"title":"📈 Risk Trend Analysis","value":"Insufficient data","trend":"stable","urgency":"normal"},{"title":"🧠 AI Confidence","value":"0%","trend":"stable","urgency":"normal"}],"alerts":[]},"...(rest of response truncated)
# ------------------------------
# 💬
# ------------------------------
# [AGENT]
# Agent input: Analyze current flood risk for the Texas:
#     1. Calculate detailed risk scores for all factors
#     2. Identify the highest risk components
#     3. Provide trend analysis
#     4. Give recommendations for monitoring
#
#     Be specific about the risk levels and factors.
# Agent's thoughts:
# k>
#
# Action: calculate_risk_score_tool
# Action Input: {"location": "Texas", "current_rainfall_mm": 0, "forecast_rainfall_mm": 0, "elevation_m": 100, "distance_to_water_km": 5, "population_density": 1000, "historical_events": 0, "usgs_flow_cfs": 0, "river_stage_ft": 0, "flood_stage_ft": 20, "weather_alerts": 0}
# ------------------------------
# 💬
# ------------------------------
# [AGENT]
# Calling tools: calculate_risk_score_tool
# Tool's input: {'location': 'Texas', 'current_rainfall_mm': 0, 'forecast_rainfall_mm': 0, 'elevation_m': 100, 'distance_to_water_km': 5, 'population_density': 1000, 'historical_events': 0, 'usgs_flow_cfs': 0, 'river_stage_ft': 0, 'flood_stage_ft': 20, 'weather_alerts': 0}
# Tool's response:
# {"status":"success","agent":"Risk Analyzer","location":"Texas","overall_risk_score":20.5,"risk_level":"Low","risk_color":"#90EE90","immediate_risk":"Low","component_scores":{"likelihood":{"total":0.0,"rainfall":0.0,"river_stage":0,"flow_rate":0,"alerts":0.0},"severity":{"total":20.5,"elevation":8,"proximity":7.5,"historical":0,"population":5}},"stage_info":{"current_stage_ft":0.0,"flood_stage_ft":20.0,"percent_of_flood_stage":0.0},"timestamp":"2025-11-14T08:17:08.477140+00:00"}
# ------------------------------
# 💬
# ------------------------------
# [AGENT]
# Agent input: Analyze current flood risk for the Texas:
#     1. Calculate detailed risk scores for all factors
#     2. Identify the highest risk components
#     3. Provide trend analysis
#     4. Give recommendations for monitoring
#
#     Be specific about the risk levels and factors.
# Agent's thoughts:
#
# Thought: I now know the final answer
# Final Answer: **Flood Risk Analysis for Texas**
#
# 1. **Detailed Risk Scores**
#    - **Overall Risk Score**: 20.5/100 (Low Risk)
#    - **Component Scores**:
#      - **Likelihood**: 0.0/100 (No active rainfall, river stages, or alerts)
#      - **Severity**: 20.5/100 (Driven by elevation, proximity to water, and population density)
#
# 2. **Highest Risk Components**
#    - **Elevation**: 8/10 (Lower elevations increase flood vulnerability)
#    - **Proximity to Water**: 7.5/10 (Average distance to water bodies is 5 km)
#    - **Population Density**: 5/10 (Moderate risk due to 1,000 people/km²)
#
# 3. **Trend Analysis**
#    - **Current Trend**: Stable (No active rainfall or rising river stages)
#    - **Data Limitation**: Insufficient historical or forecast data for long-term trends.
#
# 4. **Recommendations**
#    - **Monitoring**: Prioritize rainfall and river stage updates (current stages are 0 ft vs. flood stage of 20 ft).
#    - **Alerts**: Maintain vigilance for NOAA alerts (none active currently).
#    - **Preparedness**: Focus on low-lying areas and population centers due to elevation/proximity risks.
#
# **Conclusion**: Texas currently faces **low flood risk**, but elevation and proximity factors warrant ongoing monitoring. No immediate action required, but preparedness protocols should remain active.
# ------------------------------
#
# ================================================================================
# ✅ Data Collection Complete!
#
# **Flood Risk Analysis for Texas**
#
# 1. **Detailed Risk Scores**
#    - **Overall Risk Score**: 20.5/100 (Low Risk)
#    - **Component Scores**:
#      - **Likelihood**: 0.0/100 (No active rainfall, river stages, or alerts)
#      - **Severity**: 20.5/100 (Driven by elevation, proximity to water, and population density)
#
# 2. **Highest Risk Components**
#    - **Elevation**: 8/10 (Lower elevations increase flood vulnerability)
#    - **Proximity to Water**: 7.5/10 (Average distance to water bodies is 5 km)
#    - **Population Density**: 5/10 (Moderate risk due to 1,000 people/km²)
#
# 3. **Trend Analysis**
#    - **Current Trend**: Stable (No active rainfall or rising river stages)
#    - **Data Limitation**: Insufficient historical or forecast data for long-term trends.
#
# 4. **Recommendations**
#    - **Monitoring**: Prioritize rainfall and river stage updates (current stages are 0 ft vs. flood stage of 20 ft).
#    - **Alerts**: Maintain vigilance for NOAA alerts (none active currently).
#    - **Preparedness**: Focus on low-lying areas and population centers due to elevation/proximity risks.
#
# **Conclusion**: Texas currently faces **low flood risk**, but elevation and proximity factors warrant ongoing monitoring. No immediate action required, but preparedness protocols should remain active.
# ================================================================================

# %% [markdown]
# ### Example 2: H2OGPTE ML Agent
#
# AutoML agent for model training and optimization:

# %%
# Run H2OGPTE ML Agent via NAT
payload = {
    "agent": "h2ogpte_agent",
    "message": """Help me design an ML pipeline for flood prediction:
    1. What features should I engineer from raw sensor data?
    2. What model types work best for flood forecasting?
    3. How should I handle imbalanced flood event data?
    4. What validation strategy is appropriate for time-series?

    Provide actionable AutoML recommendations.""",
}
headers = {"Authorization": "Bearer local-token"}

print("🧠 Running H2OGPTE ML Agent...\n")

response = requests.post(
    f"{api_server_base_url}/api/nat/chat", json=payload, headers=headers
)

if response.status_code == 200:
    result = response.json()
    print("✅ ML Recommendations Complete!\n")
    print("=" * 80)
    print(result.get("response", result))
    print("=" * 80)
else:
    print(f"❌ Error: {response.status_code}")
    print(response.text)
# Out:
# 🧠 Running H2OGPTE ML Agent...
#
# ✅ ML Recommendations Complete!
#
# ================================================================================
# {'output': "**1. Feature Engineering from Raw Sensor Data**  \nEngineer features such as:  \n- **Temporal statistics**: Rolling averages (1h, 24h) of rainfall, maximum rainfall intensity.  \n- **Hydrological metrics**: Soil moisture levels, river flow rates, water stage height.  \n- **Weather context**: Forecasted rainfall, wind speed, evapotranspiration rates.  \n- **Spatial context**: Elevation, proximity to water bodies, drainage basin size.  \n\n**2. Model Recommendations**  \n- **Deep Learning**: LSTM/GRU networks for sequential data.  \n- **Gradient Boosting**: XGBoost/LightGBM for tabular data with feature interactions.  \n- **Hybrid Models**: Combine physics-based (e.g., HEC-RAS) and data-driven approaches.  \n\n**3. Handling Imbalanced Data**  \n- **Resampling**: Use SMOTE or Tomek links for synthetic minority oversampling.  \n- **Cost-Sensitive Learning**: Assign higher weights to flood events during training.  \n- **Anomaly Detection**: Frame flood prediction as an anomaly detection task (e.g., Isolation Forest).  \n\n**4. Validation Strategy**  \n- **Time-Series Cross-Validation**: Use walk-forward validation with expanding windows.  \n- **Metrics**: Focus on F1-score, precision-recall curves, and lead time-specific metrics.  \n\n**AutoML Recommendations**  \n- **H2O.ai Driverless AI**: Automates feature engineering, model selection, and hyperparameter tuning.  \n- **DataRobot**: Specialized time-series pipelines with automated validation.  \n- **PyCaret**: Open-source tool for rapid prototyping with imbalance handling.  \n\n**Example Pipeline**  \n```python\nfrom pycaret.classification import *\n\n# Initialize AutoML\nexp = setup(data, target='flood_event', \n            fold_strategy='time_series', \n            fold = 5, \n            numeric_features=['rainfall_24h', 'soil_moisture'])\n\n# Compare models\nbest_model = compare_models(fit_once=True)\n\n# Finalize and deploy\nfinal_model = finalize_model(best_model)\n```  \n\n**Key Considerations**  \n- Integrate real-time data streams (e.g., NOAA APIs, USGS gauges).  \n- Implement a feedback loop to retrain models post-flood events.  \n- Use SHAP values for explainability of risk factors.", 'agent_type': 'risk_analyzer', 'status': 'success', 'logs': [], 'timestamp': '2025-11-14T08:18:50.201358+00:00'}
# ================================================================================

# %% [markdown]
# ---
#
# # Section 5: Real-World Data Integration
#
# ## 🌐 Live Data from Government APIs
#
# Our system integrates with real-time data sources:
#
# ### Data Sources
#
# 1. **USGS Water Services**
#    - Real-time streamflow (CFS)
#    - Gage height (feet)
#    - 12 monitoring stations in Texas
#    - Updated every 15 minutes
#
# 2. **NOAA Weather Service**
#    - Flood warnings and watches
#    - Weather alerts
#    - Forecast data
#
# 3. **Open-Meteo**
#    - Weather forecasts
#    - Flood API predictions
#    - Historical data
#
# ### Let's view live watershed data:

# %% [markdown]
# ##### Refresh USGS Data Manually
#
# Trigger a fresh data collection from USGS:

# %%
print("🔄 Triggering USGS data refresh...\n")
header = {"Authorization": "Bearer local-token"}

response = requests.post(
    f"{api_server_base_url}/api/dashboard/refresh-usgs-data", headers=header
)

if response.status_code == 200:
    result = response.json()
    time.sleep(5)

else:
    print(f"❌ Error: {response.status_code}")

# Get current watershed data
response = requests.get(f"{api_server_base_url}/api/watersheds")

if response.status_code == 200:
    watersheds = response.json()

    # Convert to DataFrame for nice display
    df = pd.DataFrame(watersheds)

    # Select key columns
    display_cols = [
        "name",
        "current_streamflow_cfs",
        "risk_score",
        "trend_rate_cfs_per_hour",
        "last_updated",
    ]

    available_cols = [col for col in display_cols if col in df.columns]

    print("🌊 Live Watershed Data\n")
    print("=" * 100)
    print(df[available_cols].to_string(index=False))
    print("=" * 100)
    print(f"\n📊 Total Watersheds Monitored: {len(watersheds)}")

    # Calculate statistics
    if "risk_score" in df.columns:
        high_risk = len(df[df["risk_score"] > 7.0])
        medium_risk = len(df[(df["risk_score"] >= 4.0) & (df["risk_score"] <= 7.0)])
        low_risk = len(df[df["risk_score"] < 4.0])

        print("\n⚠️  Risk Distribution:")
        print(f"   🔴 High Risk (>7.0): {high_risk}")
        print(f"   🟡 Medium Risk (4.0-7.0): {medium_risk}")
        print(f"   🟢 Low Risk (<4.0): {low_risk}")
else:
    print(f"❌ Error fetching watersheds: {response.status_code}")
# Out:
# 🔄 Triggering USGS data refresh...
#
# ❌ Error: 500
# 🌊 Live Watershed Data
#
# ====================================================================================================
#                                                 name  current_streamflow_cfs  risk_score  trend_rate_cfs_per_hour        last_updated
#       Guadalupe River at Comfort, TX (USGS 08167000)                  2850.0         8.2                     45.2 2025-10-22 22:38:44
#         Colorado River at Austin, TX (USGS 08158000)                  3200.5         7.9                     38.7 2025-10-22 22:38:44
#     Sabine River near Gladewater, TX (USGS 08020000)                  1890.5         6.3                     22.1 2025-10-22 22:38:44
#       Brazos River near Rosharon, TX (USGS 08116650)                  1245.7         5.8                     12.4 2025-10-22 22:38:44
#         Red River at Arthur City, TX (USGS 07335500)                  1567.9         5.4                     18.6 2025-10-22 22:38:44
#         Nueces River near Mathis, TX (USGS 08211000)                   812.3         5.1                     14.7 2025-10-22 22:38:44
#          Trinity River at Dallas, TX (USGS 08057000)                   890.3         4.7                    -15.3 2025-10-22 22:38:44
#        Llano River near Junction, TX (USGS 08150000)                   423.7         4.1                      8.9 2025-10-22 22:38:44
#     Canadian River near Amarillo, TX (USGS 07227500)                   678.4         3.2                      5.1 2025-10-22 22:38:44
#          Neches River at Evadale, TX (USGS 08041000)                   445.2         2.8                     -2.3 2025-10-22 22:38:44
# San Antonio River at San Antonio, TX (USGS 08178000)                   156.8         2.1                      0.8 2025-10-22 22:38:44
#       Pecos River near Sheffield, TX (USGS 08447000)                   234.1         1.9                     -8.7 2025-10-22 22:38:44
# ====================================================================================================
#
# 📊 Total Watersheds Monitored: 12
#
# ⚠️  Risk Distribution:
#    🔴 High Risk (>7.0): 2
#    🟡 Medium Risk (4.0-7.0): 6
#    🟢 Low Risk (<4.0): 4

# %% [markdown]
# ---
#
# # 🎓 Summary & Next Steps
#
# ## What We've Learned
#
# In this notebook, you've learned how to:
#
# ✅ **Set up a multi-agent AI system** for disaster response
# ✅ **Integrate h2oGPTe** for AutoML and model training
# ✅ **Use NVIDIA NIM** for high-performance inference
# ✅ **Build NAT agent workflows** with React patterns
# ✅ **Implement FastMCP servers** with custom tools
# ✅ **Integrate real-time data** from government APIs
# ✅ **Coordinate multiple AI agents** for complex tasks
# ✅ **Evaluate responses** using LLM-as-Judge
#
# ## Architecture Highlights
#
# - **5 Specialized Agents**: Data Collector, Risk Analyzer, Emergency Responder, Predictor, H2OGPTE ML
# - **20+ MCP Tools**: Via FastMCP server on port 8001
# - **NVIDIA NIM Models**: Nemotron Super 49B, Llama 3.1 variants
# - **h2oGPTe A2A**: Agent-to-agent AutoML capabilities
# - **Real-time Data**: USGS, NOAA, Weather APIs
#
# ## Resources
#
# - **NVIDIA NIM**: [build.nvidia.com](https://build.nvidia.com)
# - **h2oGPTe**: [h2o.ai/platform/enterprise-h2ogpte](https://h2o.ai/platform/enterprise-h2ogpte/)
# - **NVIDIA NAT**: [docs.nvidia.com/nat](https://docs.nvidia.com/nat)
# - **FastMCP**: [github.com/jlowin/fastmcp](https://github.com/jlowin/fastmcp)
# - **USGS Water Data**: [waterdata.usgs.gov](https://waterdata.usgs.gov)
# - **NOAA Weather**: [weather.gov](https://weather.gov)
#
# ## Next Steps
#
# 1. **Customize Agents**: Modify agent configs for your specific use case
# 2. **Add Data Sources**: Integrate additional APIs and sensors
# 3. **Train ML Models**: Use h2oGPTe to train production models
# 4. **Deploy to Production**: Use Docker/Kubernetes deployment
# 5. **Monitor Performance**: Add logging and metrics
#
# ## Contributing
#
# This is an open-source AI for Good project. Contributions welcome!
#
# ---
#
# ### 🌊 Thank you for exploring the Flood Intelligence Blueprint!
#
# **Built with ❤️ using h2oGPTe and NVIDIA NIM**
#
# For questions and support, please open an issue in the repository.
